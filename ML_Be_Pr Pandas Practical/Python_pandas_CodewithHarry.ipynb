# %%
import numpy as np
import pandas as pd

# %%
dict1={"Name":['Shruti','Nisha','Prity','Chhoti'],
      "Marks":[80,79,82,78],
      "City":['Durgapur','Lucknow','Kolkata','Asansol']
      }

# %%
df=pd.DataFrame(dict1)

# %%
print(df)
# Out:
#      Name  Marks      City
# 0  Shruti     80  Durgapur
# 1   Nisha     79   Lucknow
# 2   Prity     82   Kolkata
# 3  Chhoti     78   Asansol

# %% [markdown]
# # What are CSV Files?
# The full form of CSV is Comma-separated values. Comma-separated value is a simple yet powerful file format to store and exchange data. Values are separated using commas in this plain text file format. CSV files are often used to store data in a tabular format, such as spreadsheets or databases. These files are easy to create and edit, are compatible with a wide variety of software applications, and are easy to share and transfer.

# %%
df.to_csv("friends.csv") #here index will show

# %%
df.to_csv("friends_no-index.csv",index=False)  #here no index will show

# %%
df.describe()
# Out:
#            Marks
# count   4.000000
# mean   79.750000
# std     1.707825
# min    78.000000
# 25%    78.750000
# 50%    79.500000
# 75%    80.500000
# max    82.000000

# %% [markdown]
# # The describe() function provides the following statistics for each numerical column in the DataFrame:
#
# count: The number of non-null entries.
# mean: The average of the entries.
# std: The standard deviation of the entries.
# min: The minimum value.
# 25%: The 25th percentile (first quartile).
# 50%: The 50th percentile (second quartile, or median).
# 75%: The 75th percentile (third quartile).
# max: The maximum value

# %%
shruti=pd.read_csv("shruti.csv")

# %%
shruti
# Out:
#    Unnamed: 0  Train  Speed      City
# 0           0   1234     50  Durgapur
# 1           1   4345    454   Lucknow
# 2           2   5254     82   Kolkata
# 3           3   5433     78   Asansol

# %%
shruti['Speed']
# Out:
# 0     50
# 1    454
# 2     82
# 3     78
# Name: Speed, dtype: int64

# %%
shruti['Speed'][0]
# Out:
# 50

# %%
shruti['Speed'][0]=50 #it will update the value
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_8736\3680812656.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shruti['Speed'][0]=50 #it will update the value

# %%
shruti
# Out:
#    Unnamed: 0  Train  Speed      City
# 0           0   1234     50  Durgapur
# 1           1   4345    454   Lucknow
# 2           2   5254     82   Kolkata
# 3           3   5433     78   Asansol

# %%
shruti.to_csv("shruti.csv")  #it will update the csv file

# %%
shruti.index=['fisrt','second','third','fourth']

# %%
shruti
# Out:
#         Unnamed: 0  Train  Speed      City
# fisrt            0   1234     50  Durgapur
# second           1   4345    454   Lucknow
# third            2   5254     82   Kolkata
# fourth           3   5433     78   Asansol

# %%
ser=pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.494202
# 1     0.994043
# 2     0.876587
# 3     0.067742
# 4     0.722857
# 5     0.161046
# 6     0.258113
# 7     0.159518
# 8     0.975092
# 9     0.301345
# 10    0.054899
# 11    0.991889
# 12    0.988654
# 13    0.444096
# 14    0.687452
# 15    0.532341
# 16    0.231750
# 17    0.208168
# 18    0.060872
# 19    0.015899
# 20    0.281970
# 21    0.901085
# 22    0.873967
# 23    0.849309
# 24    0.446581
# 25    0.604747
# 26    0.801359
# 27    0.288894
# 28    0.615671
# 29    0.907407
# 30    0.875028
# 31    0.973106
# 32    0.452448
# 33    0.863540
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf=pd.DataFrame(np.random.rand(334,5),index=np.arange(334))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0
#
# [334 rows x 5 columns]

# %%
newdf.sort_index(axis=1,ascending=False)  #axis=1 means columns
# Out:
#             4         3         2         1         0
# 0    0.699827  0.671414   0.97544  0.072592   0.05449
# 1    0.788788  0.801718  0.003352  0.359852  0.840156
# 2    0.722751  0.248116   0.03203  0.153063   0.21345
# 3    0.479236  0.809509  0.016931  0.911092  0.728964
# 4    0.234279  0.269280  0.086671  0.897667   0.56782
# ..        ...       ...       ...       ...       ...
# 329  0.934418  0.778289  0.225125  0.422557  0.481509
# 330  0.017700  0.077138  0.539661  0.157743  0.519094
# 331  0.564530  0.927586  0.457463  0.966418    0.7291
# 332  0.660122  0.206779  0.491591  0.768925  0.380874
# 333  0.584588  0.342222  0.938623  0.116588    0.4795
#
# [334 rows x 5 columns]

# %%
type(newdf[0])
# Out:
# pandas.core.series.Series

# %%
new=pd.DataFrame(np.random.rand(334,5))

# %%
new
# Out:
#             0         1         2         3         4
# 0    0.248184  0.898981  0.042499  0.980653  0.553734
# 1    0.009202  0.063221  0.630585  0.385685  0.040641
# 2    0.673660  0.516881  0.840070  0.845214  0.116841
# 3    0.375444  0.665054  0.343316  0.686855  0.766931
# 4    0.748728  0.828790  0.770558  0.122650  0.397025
# ..        ...       ...       ...       ...       ...
# 329  0.962604  0.852981  0.473025  0.888025  0.794907
# 330  0.600600  0.062052  0.376825  0.151892  0.235910
# 331  0.116679  0.791327  0.366680  0.613530  0.356390
# 332  0.791037  0.200665  0.185713  0.648305  0.786882
# 333  0.082913  0.034479  0.843598  0.981793  0.097835
#
# [334 rows x 5 columns]

# %%
newDF=new  #i changed in newDF but new also get changed

# %%
newDF[0][2]=1234

# %%
new
# Out:
#                0         1         2         3         4
# 0       0.248184  0.898981  0.042499  0.980653  0.553734
# 1       0.009202  0.063221  0.630585  0.385685  0.040641
# 2    1234.000000  0.516881  0.840070  0.845214  0.116841
# 3       0.375444  0.665054  0.343316  0.686855  0.766931
# 4       0.748728  0.828790  0.770558  0.122650  0.397025
# ..           ...       ...       ...       ...       ...
# 329     0.962604  0.852981  0.473025  0.888025  0.794907
# 330     0.600600  0.062052  0.376825  0.151892  0.235910
# 331     0.116679  0.791327  0.366680  0.613530  0.356390
# 332     0.791037  0.200665  0.185713  0.648305  0.786882
# 333     0.082913  0.034479  0.843598  0.981793  0.097835
#
# [334 rows x 5 columns]

# %%
newDF=new.copy()

# %%
newDF[1][0]=34

# %%
new
# Out:
#                0         1         2         3         4
# 0       0.248184  0.898981  0.042499  0.980653  0.553734
# 1       0.009202  0.063221  0.630585  0.385685  0.040641
# 2    1234.000000  0.516881  0.840070  0.845214  0.116841
# 3       0.375444  0.665054  0.343316  0.686855  0.766931
# 4       0.748728  0.828790  0.770558  0.122650  0.397025
# ..           ...       ...       ...       ...       ...
# 329     0.962604  0.852981  0.473025  0.888025  0.794907
# 330     0.600600  0.062052  0.376825  0.151892  0.235910
# 331     0.116679  0.791327  0.366680  0.613530  0.356390
# 332     0.791037  0.200665  0.185713  0.648305  0.786882
# 333     0.082913  0.034479  0.843598  0.981793  0.097835
#
# [334 rows x 5 columns]

# %%
newDF
# Out:
#                0          1         2         3         4
# 0       0.248184  34.000000  0.042499  0.980653  0.553734
# 1       0.009202   0.063221  0.630585  0.385685  0.040641
# 2    1234.000000   0.516881  0.840070  0.845214  0.116841
# 3       0.375444   0.665054  0.343316  0.686855  0.766931
# 4       0.748728   0.828790  0.770558  0.122650  0.397025
# ..           ...        ...       ...       ...       ...
# 329     0.962604   0.852981  0.473025  0.888025  0.794907
# 330     0.600600   0.062052  0.376825  0.151892  0.235910
# 331     0.116679   0.791327  0.366680  0.613530  0.356390
# 332     0.791037   0.200665  0.185713  0.648305  0.786882
# 333     0.082913   0.034479  0.843598  0.981793  0.097835
#
# [334 rows x 5 columns]

# %%
new.columns=list("ABCDE")

# %%
new
# Out:
#                A         B         C         D         E
# 0       0.248184  0.898981  0.042499  0.980653  0.553734
# 1       0.009202  0.063221  0.630585  0.385685  0.040641
# 2    1234.000000  0.516881  0.840070  0.845214  0.116841
# 3       0.375444  0.665054  0.343316  0.686855  0.766931
# 4       0.748728  0.828790  0.770558  0.122650  0.397025
# ..           ...       ...       ...       ...       ...
# 329     0.962604  0.852981  0.473025  0.888025  0.794907
# 330     0.600600  0.062052  0.376825  0.151892  0.235910
# 331     0.116679  0.791327  0.366680  0.613530  0.356390
# 332     0.791037  0.200665  0.185713  0.648305  0.786882
# 333     0.082913  0.034479  0.843598  0.981793  0.097835
#
# [334 rows x 5 columns]

# %%
new.loc['A',0]=12000122

# %%
new
# Out:
#                A         B         C         D         E           0
# 0       0.248184  0.898981  0.042499  0.980653  0.553734         NaN
# 1       0.009202  0.063221  0.630585  0.385685  0.040641         NaN
# 2    1234.000000  0.516881  0.840070  0.845214  0.116841         NaN
# 3       0.375444  0.665054  0.343316  0.686855  0.766931         NaN
# 4       0.748728  0.828790  0.770558  0.122650  0.397025         NaN
# ..           ...       ...       ...       ...       ...         ...
# 330     0.600600  0.062052  0.376825  0.151892  0.235910         NaN
# 331     0.116679  0.791327  0.366680  0.613530  0.356390         NaN
# 332     0.791037  0.200665  0.185713  0.648305  0.786882         NaN
# 333     0.082913  0.034479  0.843598  0.981793  0.097835         NaN
# A            NaN       NaN       NaN       NaN       NaN  12000122.0
#
# [335 rows x 6 columns]

# %%
new.drop(0,axis=1)   #it will drop the 0 column
# Out:
#                A         B         C         D         E
# 0       0.248184  0.898981  0.042499  0.980653  0.553734
# 1       0.009202  0.063221  0.630585  0.385685  0.040641
# 2    1234.000000  0.516881  0.840070  0.845214  0.116841
# 3       0.375444  0.665054  0.343316  0.686855  0.766931
# 4       0.748728  0.828790  0.770558  0.122650  0.397025
# ..           ...       ...       ...       ...       ...
# 330     0.600600  0.062052  0.376825  0.151892  0.235910
# 331     0.116679  0.791327  0.366680  0.613530  0.356390
# 332     0.791037  0.200665  0.185713  0.648305  0.786882
# 333     0.082913  0.034479  0.843598  0.981793  0.097835
# A            NaN       NaN       NaN       NaN       NaN
#
# [335 rows x 5 columns]

# %%
new.loc[[1,2],['C','D']]
# Out:
#           C         D
# 1  0.630585  0.385685
# 2  0.840070  0.845214

# %%
new.head()
# Out:
#              A         B         C         D         E   0
# 0     0.248184  0.898981  0.042499  0.980653  0.553734 NaN
# 1     0.009202  0.063221  0.630585  0.385685  0.040641 NaN
# 2  1234.000000  0.516881  0.840070  0.845214  0.116841 NaN
# 3     0.375444  0.665054  0.343316  0.686855  0.766931 NaN
# 4     0.748728  0.828790  0.770558  0.122650  0.397025 NaN

# %%
new.drop(0,axis=1)
# Out:
#                A         B         C         D         E
# 0       0.248184  0.898981  0.042499  0.980653  0.553734
# 1       0.009202  0.063221  0.630585  0.385685  0.040641
# 2    1234.000000  0.516881  0.840070  0.845214  0.116841
# 3       0.375444  0.665054  0.343316  0.686855  0.766931
# 4       0.748728  0.828790  0.770558  0.122650  0.397025
# ..           ...       ...       ...       ...       ...
# 330     0.600600  0.062052  0.376825  0.151892  0.235910
# 331     0.116679  0.791327  0.366680  0.613530  0.356390
# 332     0.791037  0.200665  0.185713  0.648305  0.786882
# 333     0.082913  0.034479  0.843598  0.981793  0.097835
# A            NaN       NaN       NaN       NaN       NaN
#
# [335 rows x 5 columns]

# %%
new.loc[:,['C','D']]
# Out:
#             C         D
# 0    0.042499  0.980653
# 1    0.630585  0.385685
# 2    0.840070  0.845214
# 3    0.343316  0.686855
# 4    0.770558  0.122650
# ..        ...       ...
# 330  0.376825  0.151892
# 331  0.366680  0.613530
# 332  0.185713  0.648305
# 333  0.843598  0.981793
# A         NaN       NaN
#
# [335 rows x 2 columns]

# %%
new.loc[[1,2],:]
# Out:
#              A         B         C         D         E   0
# 1     0.009202  0.063221  0.630585  0.385685  0.040641 NaN
# 2  1234.000000  0.516881  0.840070  0.845214  0.116841 NaN

# %%
new.loc[new['A']>0.67]
# Out:
#                A         B         C         D         E   0
# 2    1234.000000  0.516881  0.840070  0.845214  0.116841 NaN
# 4       0.748728  0.828790  0.770558  0.122650  0.397025 NaN
# 6       0.916144  0.058913  0.191946  0.525928  0.554864 NaN
# 12      0.732591  0.607390  0.190863  0.080700  0.868919 NaN
# 13      0.816375  0.341919  0.484833  0.140574  0.494122 NaN
# ..           ...       ...       ...       ...       ...  ..
# 317     0.685917  0.979582  0.216603  0.833284  0.092186 NaN
# 319     0.957794  0.305823  0.072053  0.052071  0.092321 NaN
# 323     0.770027  0.709324  0.532803  0.596737  0.074674 NaN
# 329     0.962604  0.852981  0.473025  0.888025  0.794907 NaN
# 332     0.791037  0.200665  0.185713  0.648305  0.786882 NaN
#
# [117 rows x 6 columns]

# %%
new.loc[(new['A']>0.67) & (new['D']>0.8)]
# Out:
#                A         B         C         D         E   0
# 2    1234.000000  0.516881  0.840070  0.845214  0.116841 NaN
# 31      0.932929  0.074054  0.004526  0.937093  0.013228 NaN
# 44      0.939749  0.858780  0.743379  0.947877  0.804764 NaN
# 56      0.938560  0.399609  0.379846  0.898441  0.319551 NaN
# 88      0.679764  0.545101  0.306167  0.914492  0.479764 NaN
# 105     0.756831  0.273660  0.112462  0.813472  0.772672 NaN
# 117     0.814848  0.764939  0.735737  0.821545  0.526106 NaN
# 151     0.748011  0.301865  0.032489  0.921421  0.278617 NaN
# 170     0.729678  0.087013  0.291168  0.974386  0.731909 NaN
# 187     0.942564  0.029472  0.082677  0.979819  0.830948 NaN
# 213     0.715453  0.920849  0.338832  0.801808  0.339377 NaN
# 225     0.691094  0.795143  0.175149  0.821698  0.960118 NaN
# 226     0.795836  0.481341  0.215658  0.934698  0.849424 NaN
# 249     0.830021  0.867090  0.507602  0.809179  0.471407 NaN
# ...

# %%
new.head(2)
# Out:
#           A         B         C         D         E   0
# 0  0.248184  0.898981  0.042499  0.980653  0.553734 NaN
# 1  0.009202  0.063221  0.630585  0.385685  0.040641 NaN

# %%
new.iloc[0,4]
# Out:
# 0.5537335330969306

# %%
new.iloc[[0,5],[1,3]]
# Out:
#           B         D
# 0  0.898981  0.980653
# 5  0.406843  0.821733

# %%
new=new.drop(0,axis=1)

# %%
new
# Out:
#                A         B         C         D         E
# 0       0.248184  0.898981  0.042499  0.980653  0.553734
# 1       0.009202  0.063221  0.630585  0.385685  0.040641
# 2    1234.000000  0.516881  0.840070  0.845214  0.116841
# 3       0.375444  0.665054  0.343316  0.686855  0.766931
# 4       0.748728  0.828790  0.770558  0.122650  0.397025
# ..           ...       ...       ...       ...       ...
# 330     0.600600  0.062052  0.376825  0.151892  0.235910
# 331     0.116679  0.791327  0.366680  0.613530  0.356390
# 332     0.791037  0.200665  0.185713  0.648305  0.786882
# 333     0.082913  0.034479  0.843598  0.981793  0.097835
# A            NaN       NaN       NaN       NaN       NaN
#
# [335 rows x 5 columns]

# %%
new.drop(['A','D'],axis=1,inplace=True)

# %%
new
# Out:
#             B         C         E
# 0    0.898981  0.042499  0.553734
# 1    0.063221  0.630585  0.040641
# 2    0.516881  0.840070  0.116841
# 3    0.665054  0.343316  0.766931
# 4    0.828790  0.770558  0.397025
# ..        ...       ...       ...
# 330  0.062052  0.376825  0.235910
# 331  0.791327  0.366680  0.356390
# 332  0.200665  0.185713  0.786882
# 333  0.034479  0.843598  0.097835
# A         NaN       NaN       NaN
#
# [335 rows x 3 columns]

# %%
new.drop([2,4,7],axis=0,inplace=True)

# %%
new.head()
# Out:
#           B         C         E
# 0  0.898981  0.042499  0.553734
# 1  0.063221  0.630585  0.040641
# 3  0.665054  0.343316  0.766931
# 5  0.406843  0.332956  0.607016
# 6  0.058913  0.191946  0.554864

# %%
new.reset_index(drop=True,inplace=True)

# %%
new.head()
# Out:
#           B         C         E
# 0  0.898981  0.042499  0.553734
# 1  0.063221  0.630585  0.040641
# 2  0.665054  0.343316  0.766931
# 3  0.406843  0.332956  0.607016
# 4  0.058913  0.191946  0.554864

# %%
new.loc[: ,['B']]=37

# %%
new.head()
# Out:
#       B         C         E
# 0  37.0  0.042499  0.553734
# 1  37.0  0.630585  0.040641
# 2  37.0  0.343316  0.766931
# 3  37.0  0.332956  0.607016
# 4  37.0  0.191946  0.554864

# %%
new['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 327    False
# 328    False
# 329    False
# 330    False
# 331    False
# Name: B, Length: 332, dtype: bool

# %%
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman'],
                   "toy": [np.nan, 'Batmobile', 'Bullwhip'],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"),
                            pd.NaT]})

# %%
df
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna()
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(axis=1)
# Out:
#        name
# 0    Alfred
# 1    Batman
# 2  Catwoman

# %%
df
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(how='all')
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman'],
                   "toy": [np.nan,np.nan,np.nan],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"),
                            pd.NaT]})

# %%
df
# Out:
#        name  toy       born
# 0    Alfred  NaN        NaT
# 1    Batman  NaN 1940-04-25
# 2  Catwoman  NaN        NaT

# %%
df.dropna(how='all',axis=1)
# Out:
#        name       born
# 0    Alfred        NaT
# 1    Batman 1940-04-25
# 2  Catwoman        NaT

# %%
df = pd.DataFrame({
    'brand': ['Yum Yum', 'Yum Yum', 'Indomie', 'Indomie', 'Indomie'],
    'style': ['cup', 'cup', 'cup', 'pack', 'pack'],
    'rating': [4, 4, 3.5, 15, 5]
})

# %%
df
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %%
df.drop_duplicates()  #By default, it removes duplicate rows based on all columns.
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %%
df.drop_duplicates(subset=['brand'])   #To remove duplicates on specific column
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5

# %% [markdown]
# # keep{‘first’, ‘last’, False}, default ‘first’
# Determines which duplicates (if any) to keep.
#
# ‘first’ : Drop duplicates except for the first occurrence.
#
# ‘last’ : Drop duplicates except for the last occurrence.
#
# False : Drop all duplicates.

# %%
df.drop_duplicates(subset=['brand'],keep='last')
# Out:
#      brand style  rating
# 1  Yum Yum   cup     4.0
# 4  Indomie  pack     5.0

# %%
df.drop_duplicates(subset=['brand'],keep=False)
# Out:
# Empty DataFrame
# Columns: [brand, style, rating]
# Index: []

# %%
df.shape
# Out:
# (5, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   brand   5 non-null      object
#  1   style   5 non-null      object
#  2   rating  5 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 252.0+ bytes

# %%
df['brand'].value_counts(dropna=False)
# Out:
# brand
# Indomie    3
# Yum Yum    2
# Name: count, dtype: int64

# %%
data=pd.read_excel("Excel.xlsx")

# %%
data
# Out:
#    Train  Speed      City
# 0   1234     50  Durgapur
# 1   4345    454   Lucknow
# 2   5254     82   Kolkata
# 3   5433     78   Asansol

# %%
data=pd.read_excel("Excel.xlsx",sheet_name='Sheet2')

# %%
data
# Out:
#      Name  Marks      City
# 0  Shruti     80  Durgapur
# 1   Nisha     79   Lucknow
# 2   Prity     82   Kolkata
# 3  Chhoti     78   Asansol
